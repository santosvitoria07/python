# %% [markdown]
# <a href="https://colab.research.google.com/github/santosvitoria07/python/blob/main/planilha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #** Avaliação do Curso - Professores - Técnico em Informática para Internet - Integrado**
# #Caro(a) professor(a), você está participando de uma avaliação, cujo objetivo é levantar dados que possam subsidiar melhorias no curso, ao qual ministra aulas. Agradecemos sua colaboração

# %%
import pandas as pd

# %%
dados = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQo0uYva9ycvDp0owZ3DAdzLFtucJ7pLFeeVeUOGrbe5WNuc-sFm1tuaf-iTL_Q_q32XGw238mXswy1/pub?gid=2012010921&single=true&output=csv")

# %%
dados
# Out:
#   Carimbo de data/hora  Pontuação  \
# 0                  NaN        NaN
# 1  14/09/2022 11:03:16        NaN
# 2  14/09/2022 11:09:31        NaN
# 3  14/09/2022 11:16:30        NaN
# 4  14/09/2022 14:09:54        NaN
# 5  14/09/2022 15:00:42        NaN
# 6  14/09/2022 15:18:14        NaN
# 7  14/09/2022 15:48:19        NaN
# 8  15/09/2022 08:50:43        NaN
# 9  15/09/2022 10:14:08        NaN
#
#   Estrutura Física da escola - Avalie a estrutura física de sala de aula   \
# 0                                                NaN
# 1                                                Bom
# 2                                          Excelente
# 3                                                Bom
# 4                                          Excelente
# 5                                          Excelente
# 6                                          Excelente
# 7                                                Bom
# 8                                          Excelente
# ...

# %%
dados.hist()
# Out:
# array([[<Axes: title={'center': 'Pontuação'}>]], dtype=object)

# %%
dados['Aprendizagem dos alunos -  os simpósios, seminários, semanas de estudos e outros eventos\nsão articulados com o desenvolvimento do curso.'].hist()
# Out:
# <Axes: >

# %%
dados['Aprendizagem dos alunos - a articulação entre teoria e prática.'].hist()
# Out:
# <Axes: >

# %%
dados['Aprendizagem dos alunos - O interesse dos alunos com a formação ética e cidadã'].hist()
# Out:
# <Axes: >

# %%
dados['Aprendizagem dos alunos - a assiduidade e pontualidade dos alunos em suas atividades em sala de aula, atendimento e orientações'].hist()
# Out:
# <Axes: >

# %%
dados['Aprendizagem dos alunos - a compreensão e a relação entre o mundo do trabalho e o perfil profissional desejado para o seu curso.'].hist()
# Out:
# <Axes: >

# %%
dados['Aprendizagem dos alunos -  os simpósios, seminários, semanas de estudos e outros eventos\nsão articulados com o desenvolvimento do curso.'].value_counts()
# Out:
# Aprendizagem dos alunos -  os simpósios, seminários, semanas de estudos e outros eventos\nsão articulados com o desenvolvimento do curso.
# Bom             4
# Excelente       3
# Satisfatório    2
# Name: count, dtype: int64

# %%
dados['Aprendizagem dos alunos -  os simpósios, seminários, semanas de estudos e outros eventos\nsão articulados com o desenvolvimento do curso.'].describe()
# Out:
# count       9
# unique      3
# top       Bom
# freq        4
# Name: Aprendizagem dos alunos -  os simpósios, seminários, semanas de estudos e outros eventos\nsão articulados com o desenvolvimento do curso., dtype: object
